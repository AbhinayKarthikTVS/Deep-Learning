# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinayKarthikTVS/AbhinayKarthikTVS/blob/main/Traffic_Sign_Detection_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# !pip install -r yolov5/requirements.txt
# !cd /content/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...

# %%
# !python /content/yolov5/detect.py --source /content/drive/MyDrive/Images --weights /content/drive/MyDrive/RealTime_Detection-And-Classification-of-TrafficSigns-main/Model/weights/best.pt --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/RealTime_Detection-And-Classification-of-TrafficSigns-main/Model/weights/best.pt'], source=/content/drive/MyDrive/Images, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 232 layers, 7451490 parameters, 0 gradients
# image 1/150 /content/drive/.shortcut-targets-by-id/1-CTAugZ-WkTtSZic5gX3ib6oN273csQ3/batch/Datacluster Traffic Sign (1).jpg: 640x480 (no detections), 507.1ms
# ...
